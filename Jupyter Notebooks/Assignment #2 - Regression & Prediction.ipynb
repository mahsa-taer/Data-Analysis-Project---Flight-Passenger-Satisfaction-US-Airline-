# %% [markdown]
# <div class="alert alert-block alert-info"><b><h1>Regression & Prediction </h1></b></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Getting the heatmap plot on correlation matrix</em></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Test Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df_test = pd.read_csv("Airline_Passenger_Satisfaction_Test_Cleaned.csv")

# Correlation matrix
plt.figure(figsize=(30,30))
corr=df_test.corr()
print (corr)

# Plot Heatmap on correlation matrix 
sns.heatmap(corr, annot=True, cmap='YlGnBu')

# display the plot
plt.show()
# Out:
#                                        id       Age  FlightDistance  \
# id                               1.000000  0.008716        0.128057
# Age                              0.008716  1.000000        0.071084
# FlightDistance                   0.128057  0.071084        1.000000
# InflightWifiservice             -0.033685  0.010341        0.006385
# DepartureArrivalTimeCconvenient -0.002621  0.036373       -0.002119
# EaseOfOnlineBooking              0.009628  0.013755        0.057598
# GateLocation                     0.000522  0.004032        0.009981
# FoodAndDrink                    -0.011324  0.024364        0.051803
# OnlineBoarding                   0.051801  0.198961        0.187121
# SeatComfort                      0.043123  0.149535        0.137294
# InflightEntertainment           -0.001082  0.063672        0.117435
# OnBoardService                   0.057446  0.045660        0.103786
# LegRoomService                   0.043511  0.022374        0.118800
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Train Dataset

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

df_train = pd.read_csv("Airline_Passenger_Satisfaction_Train_Cleaned.csv")

# Correlation matrix
plt.figure(figsize=(30,30))
corr=df_train.corr()
print (corr)

# Plot Heatmap on correlation matrix 
sns.heatmap(corr, annot=True, cmap='YlGnBu')

# display the plot
plt.show()
# Out:
#                                        id       Age  FlightDistance  \
# id                               1.000000  0.021513        0.122290
# Age                              0.021513  1.000000        0.072044
# FlightDistance                   0.122290  0.072044        1.000000
# InflightWifiservice             -0.026822  0.018756        0.005155
# DepartureArrivalTimeCconvenient -0.002813  0.041578       -0.011502
# EaseOfOnlineBooking              0.013278  0.024639        0.060581
# GateLocation                    -0.002803 -0.002377        0.000523
# FoodAndDrink                    -0.002401  0.024392        0.046172
# OnlineBoarding                   0.049450  0.205780        0.179179
# SeatComfort                      0.045659  0.156164        0.131846
# InflightEntertainment           -0.000563  0.071464        0.100438
# OnBoardService                   0.053700  0.048974        0.090312
# LegRoomService                   0.042865  0.028883        0.114357
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Getting the top 5 records in the dataset</em></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Test Dataset

# %%
df_test = pd.read_csv("Airline_Passenger_Satisfaction_Test_Cleaned.csv")
df_test.head()
# Out:
#       id  Gender       CustomerType  Age     TypeOfTravel     Class  \
# 0  19556  Female     Loyal Customer   52  Business travel       Eco
# 1  90035  Female     Loyal Customer   36  Business travel  Business
# 2  12360    Male  disloyal Customer   20  Business travel       Eco
# 3  36875  Female     Loyal Customer   49  Business travel       Eco
# 4  39177    Male     Loyal Customer   16  Business travel       Eco
#
#    FlightDistance  InflightWifiservice  DepartureArrivalTimeCconvenient  \
# 0             160                    5                                4
# 1            2863                    1                                1
# 2             192                    2                                0
# 3            1182                    2                                3
# 4             311                    3                                3
#
#    EaseOfOnlineBooking  ...  InflightEntertainment  OnBoardService  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Train Dataset

# %%
df_train = pd.read_csv("Airline_Passenger_Satisfaction_Train_Cleaned.csv")
df_train.head()
# Out:
#        id  Gender       CustomerType  Age     TypeOfTravel     Class  \
# 0   70172    Male     Loyal Customer   13  Personal Travel  Eco Plus
# 1    5047    Male  disloyal Customer   25  Business travel  Business
# 2  110028  Female     Loyal Customer   26  Business travel  Business
# 3   24026  Female     Loyal Customer   25  Business travel  Business
# 4  119299    Male     Loyal Customer   61  Business travel  Business
#
#    FlightDistance  InflightWifiservice  DepartureArrivalTimeCconvenient  \
# 0             460                    3                                4
# 1             235                    3                                2
# 2            1142                    2                                2
# 3             562                    2                                5
# 4             214                    3                                3
#
#    EaseOfOnlineBooking  ...  InflightEntertainment  OnBoardService  \
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><b><h3>Data Preparation for the Prediction Using a Test and Train Set</h3></b></div>

# %%
df_train = pd.read_csv("Airline_Passenger_Satisfaction_Train_Cleaned.csv")
df_test = pd.read_csv("Airline_Passenger_Satisfaction_Test_Cleaned.csv")

def conv_cat(data):
    data['CustomerType'] = data['CustomerType'].map({'Loyal Customer': 1, 'disloyal Customer': 0})
    data['TypeOfTravel'] = data['TypeOfTravel'].map({'Personal Travel':0, 'Business travel':1})
    data['Class'] = data['Class'].map({'Business':2, 'Eco Plus':1, 'Eco':0})
    data['satisfaction'] = data['satisfaction'].map({'neutral or dissatisfied':0, 'satisfied':1})
    data = pd.get_dummies(data)
    data.drop('id',axis=1,inplace=True)
    data.fillna(0,inplace=True)
    return data
df_train = conv_cat(df_train)
df_test = conv_cat(df_test)

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Test Dataset

# %%
df_test
# Out:
#        CustomerType  Age  TypeOfTravel  Class  FlightDistance  \
# 0                 1   52             1      0             160
# 1                 1   36             1      2            2863
# 2                 0   20             1      0             192
# 3                 1   49             1      0            1182
# 4                 1   16             1      0             311
# ...             ...  ...           ...    ...             ...
# 24327             0   34             1      2             526
# 24328             1   23             1      2             646
# 24329             1   17             0      0             828
# 24330             1   14             1      2            1127
# 24331             1   42             0      0             264
#
#        InflightWifiservice  DepartureArrivalTimeCconvenient  \
# 0                        5                                4
# 1                        1                                1
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Train Dataset

# %%
df_train
# Out:
#        CustomerType  Age  TypeOfTravel  Class  FlightDistance  \
# 0                 1   13             0      1             460
# 1                 0   25             1      2             235
# 2                 1   26             1      2            1142
# 3                 1   25             1      2             562
# 4                 1   61             1      2             214
# ...             ...  ...           ...    ...             ...
# 97242             0   23             1      0             192
# 97243             1   49             1      2            2347
# 97244             0   30             1      2            1995
# 97245             0   22             1      0            1000
# 97246             1   27             1      2            1723
#
#        InflightWifiservice  DepartureArrivalTimeCconvenient  \
# 0                        3                                4
# 1                        3                                2
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><b><h3>Linear Regression</h3></b></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Here, we choose the predictors and the target, and we create test and train sets. Then, we create the linear regression model and predict. Then, we get the model coefficients and intercept.</em></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Test Dataset

# %%
# Independent variables or Features == Predictors
X = df_train.drop("FlightDistance",axis=1)
 
# Dependent or Target variable == the target value
y = df_train["FlightDistance"]

# %%
# Import train_test_split function from 
from sklearn.model_selection import train_test_split
import numpy as np
 
# Split X and y into training and testing sets == x is the input and y is the target
np.random.seed(42)
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.25)
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((72935, 23), (24312, 23), (72935,), (24312,))

# %%
# Import linear regression model
from sklearn.linear_model import LinearRegression
 
# Create linear regression model
lin_reg = LinearRegression()
 
# Fit the linear regression model
lin_reg.fit(X_train, y_train)
 
# Predict the values given test set
predictions = lin_reg.predict(X_test)
actual_prediction_df = pd.DataFrame({'Actual': y_test, 'Predicted': predictions})

# Print the intercept and coefficients
print(lin_reg.intercept_)
print(lin_reg.coef_)
print(actual_prediction_df)
# Out:
# 284.0008901363087
# [ 4.10176306e+02 -1.96796853e+00  1.88947658e+02  2.33534385e+02
#  -5.19264371e+01  3.46243015e+00  2.81641432e+01  1.74102000e+00
#  -6.34637304e+00  2.37339932e+01  1.32569456e+01 -2.52412736e+00
#   6.94453197e+00  2.35632405e+01 -2.01095062e+00  3.36125410e+00
#  -7.97950613e+00  2.19055497e+00  1.10432399e+00 -1.08649242e+00
#   2.29306553e+01 -6.13667140e-02  6.13667140e-02]
#        Actual    Predicted
# 89541    1958  1433.347480
# 30139     632   670.915643
# 41480    2422   697.782471
# 7705     1496   788.042877
# 87531    1586  1539.463995
# ...       ...          ...
# 53922     867   830.514752
# 46677     867   480.851493
# 37791      74   788.969641
# 885       337   867.384996
# 25173     255  1456.511114
#
# [24312 rows x 2 columns]

# %%
# Import the required libraries
import numpy as np
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
 
# Evaluate mean absolute error
print('Mean Absolute Error(MAE):', mean_absolute_error(y_test,predictions))  
 
# Evaluate mean squared error
print("Mean Squared Error(MSE):", mean_squared_error(y_test, predictions))  
 
# Evaluate root mean squared error
print("Root Mean Squared Error(RMSE):", np.sqrt(mean_squared_error(y_test, predictions)))
 
# Evaluate R2-square
print("R2-Square:",r2_score(y_test, predictions))
# Out:
# Mean Absolute Error(MAE): 569.7187158897176
# Mean Squared Error(MSE): 503690.8659253301
# Root Mean Squared Error(RMSE): 709.7118189274645
# R2-Square: 0.1905640685447373

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Here, we get the scatter linear regression for the actual Flight Distance vs. the predicted Flight Distance.</em></div>

# %%
from sklearn.linear_model import LinearRegression
import seaborn as sns

plt.scatter(y_test, predictions, color = "red")
plt.plot(range(2000), range(2000))
plt.title("Actual Flight Distance vs Predicted Flight Distance")
plt.xlabel("Actual Flight Distance")
plt.ylabel("Predicted Flight Distance")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Using the above model, the expected values of Total Amount Spent given that: <b>CustomerType = 1, Age = 90, TypeOfTravel = 0, Class = 0, InflightWifiservice = 4, DepartureArrivalTimeCconvenient = 5, EaseOfOnlineBooking = 3, GateLocation = 1, FoodAndDrink = 4, OnlineBoarding = 3, SeatComfort = 2, InflightEntertainment = 1, OnBoardService = 4, LegRoomService = 3, BaggageHandling = 1, CheckinService = 1, InflightService = 2, Cleanliness = 3, DepartureDelayInMinutes = 100, ArrivalDelayInMinutes = 5, Satisfaction = 0, Gender_Female = 0, Gender_Male = 1</b>

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd

data = {'CustomerType': [1], 'Age': [90], 
        'TypeOfTravel': [0], 'Class': [0], 'InflightWifiservice': [4], 
        'DepartureArrivalTimeCconvenient': [5], 'EaseOfOnlineBooking': [3], 
        'GateLocation': [1], 'FoodAndDrink': [4], 'OnlineBoarding': [3], 
        'SeatComfort': [2], 'InflightEntertainment': [1], 'OnBoardService': [4], 
        'LegRoomService': [3], 'BaggageHandling': [1], 'CheckinService': [1], 
        'InflightService': [2], 'Cleanliness': [3], 'DepartureDelayInMinutes': [100], 
        'ArrivalDelayInMinutes': [5], 'satisfaction': [0], 'Gender_Female': [0], 'Gender_Male': [1]}
X_test = pd.DataFrame(data)

predictions = lin_reg.predict(X_test)
print(predictions)
# Out:
# [678.19824137]

# %% [markdown]
# <div class="alert alert-block alert-info"><b><h3>Logistic Regression</h3></b></div>

# %% [markdown]
# <div class="alert alert-block alert-info"><b><h3>Data Preparation for the Prediction Using a Test and Train Set</h3></b></div>

# %%
df_train = pd.read_csv("Airline_Passenger_Satisfaction_Train_Cleaned.csv")
df_test = pd.read_csv("Airline_Passenger_Satisfaction_Test_Cleaned.csv")

def conv_cat(data):
    data['CustomerType'] = data['CustomerType'].map({'Loyal Customer': 1, 'disloyal Customer': 0})
    data['TypeOfTravel'] = data['TypeOfTravel'].map({'Personal Travel':0, 'Business travel':1})
    data['Class'] = data['Class'].map({'Business':2, 'Eco Plus':1, 'Eco':0})
    data['satisfaction'] = data['satisfaction'].map({'neutral or dissatisfied':0, 'satisfied':1})
    data = pd.get_dummies(data)
    data.drop('id',axis=1,inplace=True)
    data.fillna(0,inplace=True)
    return data
df_train = conv_cat(df_train)
df_test = conv_cat(df_test)

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Getting the top 5 records in the dataset</em></div>

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Test Dataset

# %%
df_train.head()
# Out:
#    CustomerType  Age  TypeOfTravel  Class  FlightDistance  \
# 0             1   13             0      1             460
# 1             0   25             1      2             235
# 2             1   26             1      2            1142
# 3             1   25             1      2             562
# 4             1   61             1      2             214
#
#    InflightWifiservice  DepartureArrivalTimeCconvenient  EaseOfOnlineBooking  \
# 0                    3                                4                    3
# 1                    3                                2                    3
# 2                    2                                2                    2
# 3                    2                                5                    5
# 4                    3                                3                    3
#
#    GateLocation  FoodAndDrink  ...  LegRoomService  BaggageHandling  \
# 0             1             5  ...               3                4
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><em>Train Dataset

# %%
df_test.head()
# Out:
#    CustomerType  Age  TypeOfTravel  Class  FlightDistance  \
# 0             1   52             1      0             160
# 1             1   36             1      2            2863
# 2             0   20             1      0             192
# 3             1   49             1      0            1182
# 4             1   16             1      0             311
#
#    InflightWifiservice  DepartureArrivalTimeCconvenient  EaseOfOnlineBooking  \
# 0                    5                                4                    3
# 1                    1                                1                    3
# 2                    2                                0                    2
# 3                    2                                3                    4
# 4                    3                                3                    3
#
#    GateLocation  FoodAndDrink  ...  LegRoomService  BaggageHandling  \
# 0             4             3  ...               5                5
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Here, we choose the predictors and the target, and we create test and train sets. Then, we create the logistic regression model and predict. Then, we get the model coefficients and intercept.</em></div>

# %%
# split dataset in two parts: feature set and target label 
features = df_train.drop("satisfaction",axis=1)
target = df_train["satisfaction"]

# partition data into training and testing set 
from sklearn.model_selection import train_test_split
import numpy as np
np.random.seed(42)
feature_train, feature_test, target_train, target_test = train_test_split(features, target, test_size=0.3)
feature_train.shape, feature_test.shape, target_train.shape, target_test.shape
# Out:
# ((68072, 23), (29175, 23), (68072,), (29175,))

# %%
# import logistic regression scikit-learn model
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score # for performance evaluation
 
# instantiate the model
logreg = LogisticRegression(solver='lbfgs')
 
# fit the model with data
logreg.fit(feature_train,target_train)
 
# Forecast the target variable for given test dataset
predictions = logreg.predict(feature_test)
#print(abs(predictions - target_test))

 
# Assess model performance using accuracy measure
print("Logistic Regression Model Accuracy:",accuracy_score(target_test, predictions))

print (logreg.intercept_)
print (logreg.coef_)

from sklearn import metrics
cnf_matrix = metrics.confusion_matrix(target_test, predictions)
print (cnf_matrix)


print("Accuracy:",metrics.accuracy_score(target_test, predictions))

print ("F1: ", metrics.f1_score(target_test, predictions, average='binary'))
# Out:
# Logistic Regression Model Accuracy: 0.7881405312767781
# [-0.25509962]
# [[ 2.25628625e-02 -2.68658258e-02  2.77728858e-01  7.04669849e-01
#    1.43472951e-05  3.32877635e-01 -3.26983826e-01  5.38252521e-02
#   -2.99096294e-01 -2.84123782e-01  5.85758599e-01  2.80222626e-02
#    2.61348412e-01  1.29396727e-01  1.03417300e-01 -1.58746281e-01
#   -5.81044307e-02 -1.86836314e-01 -6.40422749e-02 -6.56884284e-03
#   -1.79677205e-04 -1.55355850e-01 -9.97371799e-02]]
# [[13699  3544]
#  [ 2637  9295]]
# Accuracy: 0.7881405312767781
# F1:  0.7504743450002018
# C:\Users\fatem\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# <div class="alert alert-block alert-info"><em>Using the above model, the expected values of satisfaction given that: <b>CustomerType = 1, Age = 90, TypeOfTravel = 0, Class = 0, FlightDistance = 2500, InflightWifiservice = 4, DepartureArrivalTimeCconvenient = 5, EaseOfOnlineBooking = 3, GateLocation = 1, FoodAndDrink = 4, OnlineBoarding = 3, SeatComfort = 2, InflightEntertainment = 1, OnBoardService = 4, LegRoomService = 3, BaggageHandling = 1, CheckinService = 1, InflightService = 2, Cleanliness = 3, DepartureDelayInMinutes = 100, ArrivalDelayInMinutes = 5, Gender_Female = 0, Gender_Male = 1</b>

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd

import pandas
data = {'CustomerType': [1], 'Age': [90], 'TypeOfTravel': [0], 
        'Class': [0], 'FlightDistance': [2500], 'InflightWifiservice': [4], 
        'DepartureArrivalTimeCconvenient': [5], 'EaseOfOnlineBooking': [3], 
        'GateLocation': [1], 'FoodAndDrink': [4], 'OnlineBoarding': [3], 
        'SeatComfort': [2], 'InflightEntertainment': [1], 'OnBoardService': [4], 
        'LegRoomService': [3], 'BaggageHandling': [1], 'CheckinService': [1], 
        'InflightService': [2], 'Cleanliness': [3], 'DepartureDelayInMinutes': [100], 
        'ArrivalDelayInMinutes': [5], 'Gender_Female': [0], 'Gender_Male': [1]}

X_test = pd.DataFrame(data)

predictions = logreg.predict(X_test)
print(predictions)
# Out:
# [0]

# %%
from sklearn.linear_model import LogisticRegression
import pandas as pd

import pandas
data_1 = {'CustomerType': [1], 'Age': [26], 'TypeOfTravel': [1], 
          'Class': [2], 'FlightDistance': [1142], 'InflightWifiservice': [2], 
          'DepartureArrivalTimeCconvenient': [2], 'EaseOfOnlineBooking': [2], 
          'GateLocation': [2], 'FoodAndDrink': [5], 'OnlineBoarding': [5], 
          'SeatComfort': [5], 'InflightEntertainment': [5], 'OnBoardService': [4], 
          'LegRoomService': [3], 'BaggageHandling': [4], 'CheckinService': [4], 
          'InflightService': [4], 'Cleanliness': [5], 'DepartureDelayInMinutes': [0], 
          'ArrivalDelayInMinutes': [0], 'Gender_Female': [1], 'Gender_Male': [0]}

X_test_1 = pd.DataFrame(data_1)

predictions = logreg.predict(X_test_1)
print(predictions)
# Out:
# [1]
